# %%
def chatbot():
  response={
      "hi":"HI! How may I help you?",
      "Who are you?":"I am a chatbot designed to assist you",
      "what is your name?":"MY name is coding chatbot.",
      "how can you assist me?":"I will help you in your coding journey!",
      "what is a for loop?": "A for loop is used to iterate over a sequence (like a list, tuple, or string) and execute a block of code a specific number of times.",
      "what is a variable?": "A variable is like a container or a storage location that holds data or a value that can change during program execution.",
      "what is a function?": "A function is a reusable block of code that only runs when it is called. You can pass data (parameters) into it.",
      "what is a dictionary?": "In Python, a dictionary is an unordered collection of data values stored in key-value pairs, just like this chatbot memory!",
      "what is a list?": "A list is an ordered, changeable collection of items enclosed in square brackets [], used to store multiple items in a single variable.",
      "what is python?": "Python is a high-level, interpreted programming language known for its clear syntax and readability.",
      "what is an if statement?": "An if statement is a conditional statement used to execute a block of code only if a specified condition evaluates to True.",
      "how are you?": "I'm just a bundle of code, but I'm running perfectly! How are you?",
      "what is your favorite language?": "Python, of course! It's the language that gave me life.",
      "help": "You can ask me definitions like 'what is a for loop?', 'what is a list?', or say 'hi'!"
  }

  print("chatbot responding, press exit to end this converstation")

  while True:

    user_input=input("user side:").strip().lower()

    if user_input =="exit":
      print("thanks for using, goodbye!")
      break

    elif user_input in response:
      print("chatbot: ", response[user_input])

    else:
      print("we are still working on it")

chatbot()
# Out:
# chatbot responding, press exit to end this converstation
# user side:hi
# chatbot:  HI! How may I help you?
# user side:what is a for loop?
# chatbot:  A for loop is used to iterate over a sequence (like a list, tuple, or string) and execute a block of code a specific number of times.
# user side:what is a function?
# chatbot:  A function is a reusable block of code that only runs when it is called. You can pass data (parameters) into it.
